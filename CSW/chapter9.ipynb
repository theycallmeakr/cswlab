# %%
class Myclass:
    x=5
obj=Myclass()
obj2=Myclass()
print(obj.x)

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
p1=person("bt",18)
print(p1.name)
print(p1.age)
p2=person("ayush",19)
print(p2.name)
print(p2.age)
# Out:
# '{' expected
# class person:
#             ^

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
p1=person("bt",18)
print(p1.name)
print(p1.age)
p2=person("ayush",19)
print(p2.name)
print(p2.age)
del p1
print(p1.name)
# Out:
# bt
# 18
# ayush
# 19
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 print(p2.age)
#      11 del p1
# ---> 12 print(p1.name)
#
# NameError: name 'p1' is not defined

# %%
class calculator:
    def _add_(self,a,b):
        return a+b
    def _sub_(self,a,b):
        return a-b
    def _mul_(self,a,b):
        return a*b
    def _div_(self,a,b):
        return a/b
calc=calculator()
print(calc._add_(5,3))
print(calc._sub_(5,3))
print(calc._mul_(5,3))
print(calc._div_(5,3))
# Out:
# 8
# 2
# 15
# 1.6666666666666667

# %%
class playlist:
    def _init_(self):
        self.songs=[]
    def add_song(self,song):
        self.songs.append(song)
    def remove_song(self,song):
        self.songs.remove(song)
    def display_songs(self):
        for song in self.songs:
            print(song)
my_playlist=playlist("favorites")
my_playlist.add_song("song1")
my_playlist.add_song("song2")
my_playlist.display_songs()
