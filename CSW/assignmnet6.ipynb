# %%
class Student:
    def __init__(self, name, roll):
        self.name = name
        self.roll = roll

    def display(self):
        print(f"Name: {self.name}, Roll Number: {self.roll}")


students = []

n = int(input("How many students do you want to add? "))

for i in range(n):
    print(f"\nEnter details for student {i+1}:")
    name = input("Enter name: ")
    roll = input("Enter roll number: ")

    s = Student(name, roll)

    students.append(s)

print("\n Student Details-x4")
for s in students:
    s.display()
# Out:
# Enter details for student 1:
#
# Enter details for student 2:
#
# --- Student Details ---
# Name: ak, Roll Number: 34
# Name: bt, Roll Number: 57

# %%
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def __str__(self):
        return f"{self.name}({self.species})"


a = Animal("Lucy", "Cat")
print(a)
b= Animal("Max", "Dog")
print(b)
# Out:
# Lucy(Cat)

# %%
class Person:
    def __init__(self, gender):
        self.gender = gender

class College:
    def __init__(self):
        self.student1 = Person("female")
        self.student2 = Person("male")

c = College()
print("Student 1 gender:", c.student1.gender)
print("Student 2 gender:", c.student2.gender)
# Out:
# Student 1 gender: female
# Student 2 gender: male

# %%
class Car:
    def __init__(self, v1, v2):
        self.make = v1
        self.model = v2

    def get_make(self):
        return self.make

    def get_model(self):
        return self.model

    def set_make(self, make):
        self.make = make

    def set_model(self, model):
        self.model = model

car1 = Car("Toyota", "Corolla")
car2 = Car(None, None)

print("Car 1 Details:")
print("Make:", car1.get_make())
print("Model:", car1.get_model())

print("\nCar 2 Details (Before Update):")
print("Make:", car2.get_make())
print("Model:", car2.get_model())

car2.set_make("Honda")
car2.set_model("Civic")

print("\nCar 2 Details (After Update):")
print("Make:", car2.get_make())
print("Model:", car2.get_model())

# %%
#q5
class Image:
    def __init__(self, imageWidth=None, imageHeight=None, colorCode=None):
        self.imageWidth = imageWidth
        self.imageHeight = imageHeight
        self.colorCode = colorCode

    def set_width(self, width):
        self.imageWidth = width

    def set_height(self, height):
        self.imageHeight = height

    def set_color_code(self, color):
        self.colorCode = color

    def get_width(self):
        return self.imageWidth

    def get_height(self):
        return self.imageHeight

    def get_color_code(self):
        return self.colorCode

    def __str__(self):
        return f"Image Details:\nWidth: {self.imageWidth}\nHeight: {self.imageHeight}\nColor Code: {self.colorCode}"


img1 = Image()
img1.set_width(1920)
img1.set_height(1080)
img1.set_color_code("#FF5733")

img2 = Image(800, 600, "#00FF00")

print("Object 1:")
print(img1)

print("\nObject 2:")
print(img2)
# Out:
# Object 1:
# Image Details:
# Width: 1920
# Height: 1080
# Color Code: #FF5733
#
# Object 2:
# Image Details:
# Width: 800
# Height: 600
# Color Code: #00FF00
